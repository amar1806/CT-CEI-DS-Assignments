# %% [markdown]
# <a href="https://colab.research.google.com/github/amar1806/CT-CEI-DS-Assignments/blob/main/Week5_Amarjeet_Kumar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Deep Learning Text Generation Learning Project
# ## Text Generation using **Vanilla RNN, LSTM, and GRU**
#
# This notebook is built for **students and beginners** to understand how sequence models learn:
# - grammar
# - sentence flow
# - contextual dependencies
# - next-word prediction
# - text generation
#
# 🎯 **Goal:** Compare **Simple RNN vs LSTM vs GRU** on the same text corpus and understand why gated architectures perform better.

# %% [markdown]
# # 🧠 Problem Statement
# Design and implement a DL model capable of learning the underlying structure, grammar, and contextual dependencies of a given text corpus to generate coherent and meaningful text sequences using:
#
# 1. **Vanilla RNN**
# 2. **LSTM**
# 3. **GRU**
#
# Then compare:
# - training loss
# - generated text quality
# - memory handling
# - long-term dependency learning

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
import numpy as np
import matplotlib.pyplot as plt
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 📥 Load Text Corpus
# We use a **small built-in sample corpus** so students can run this quickly.
# You can later replace it with:
# - Shakespeare text
# - song lyrics
# - chatbot data
# - story paragraphs
# - custom PDF extracted text

# %% [markdown]
# **Experiment 1 : Shakespeare Text**

# %%
corpus = """
To be or not to be that is the question.
All the world's a stage and all the men and women merely players.
Some are born great some achieve greatness and some have greatness thrust upon them.
The course of true love never did run smooth.
"""
print(corpus)
# Out:
# To be or not to be that is the question.
# All the world's a stage and all the men and women merely players.
# Some are born great some achieve greatness and some have greatness thrust upon them.
# The course of true love never did run smooth.

# %% [markdown]
# **Experiment 2 : Song Lyrics**

# %%
# corpus = """
# The morning sun is shining bright.
# Birds are singing in the light.
# Walking slowly through the rain.
# Smiling softly once again.
# Music fills the silent night.
# Dreams are flying like a kite.
# """
# print(corpus)

# %% [markdown]
# **Experiment 3 : Chatbot Data**

# %%
# corpus = """
# User hello
# Bot hello how can I help you today
# User tell me about artificial intelligence
# Bot artificial intelligence enables machines to learn from data
# User what is deep learning
# Bot deep learning uses neural networks with many layers
# User thank you
# Bot you are welcome
# """
# print(corpus)

# %% [markdown]
# **Experiment 4 : Story Paragraph**

# %%
# corpus = """
# A young explorer entered an ancient forest searching for hidden treasure.
# The trees whispered as the wind passed through the branches.
# After hours of walking he discovered a glowing cave.
# Inside the cave an old map pointed toward a forgotten castle.
# The journey became the greatest adventure of his life.
# """
# print(corpus)

# %% [markdown]
# **Experiment 5 : Custom PDF Extracted Text**

# %%
# corpus = """
# MAHARISHI MARKANDESHWAR
# (DEEMED TO BE UNIVERSITY)
# Formal Language and Automata Theory
# (BCSE-515)
# REAL-LIFE EXAMPLE - 01
# on
# Syntax Analysis in Programming Languages using
# Pushdown Automata
# """
# print(corpus)

# %% [markdown]
# # 🔤 Tokenization & Sequence Creation
# We convert text into integer tokens and create **n-gram style sequences**
# for next-word prediction.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([corpus])

total_words = len(tokenizer.word_index) + 1
print("Vocabulary size:", total_words)

input_sequences = []
for line in corpus.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_seq = token_list[:i+1]
        input_sequences.append(n_gram_seq)

max_len = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# Vocabulary size: 36
# X shape: (42, 13)
# y shape: (42,)

# %% [markdown]
# # 🧠 Model 1: Vanilla RNN
# This is the baseline sequential model.
# It struggles with long-term dependencies because of vanishing gradients.

# %%
rnn_model = Sequential([
    Embedding(total_words, 64, input_length=max_len-1),
    SimpleRNN(128),
    Dense(total_words, activation='softmax')
])

rnn_model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

rnn_history = rnn_model.fit(X, y, epochs=200, verbose=0)
print("Vanilla RNN training completed")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Vanilla RNN training completed

# %% [markdown]
# # 🔒 Model 2: LSTM
# LSTM uses **input, forget, and output gates**
# to preserve long-term memory.

# %%
lstm_model = Sequential([
    Embedding(total_words, 64, input_length=max_len-1),
    LSTM(128),
    Dense(total_words, activation='softmax')
])

lstm_model.compile(loss='sparse_categorical_crossentropy',
                   optimizer='adam',
                   metrics=['accuracy'])

lstm_history = lstm_model.fit(X, y, epochs=200, verbose=0)
print("LSTM training completed")
# Out:
# LSTM training completed

# %% [markdown]
# # ⚡ Model 3: GRU
# GRU uses **reset + update gates**.
# It is computationally faster than LSTM and often gives similar results.

# %%
gru_model = Sequential([
    Embedding(total_words, 64, input_length=max_len-1),
    GRU(128),
    Dense(total_words, activation='softmax')
])

gru_model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

gru_history = gru_model.fit(X, y, epochs=200, verbose=0)
print("GRU training completed")
# Out:
# GRU training completed

# %% [markdown]
# ## 📉 Compare Training Loss

# %%
plt.figure(figsize=(10,4))
plt.plot(rnn_history.history['loss'], label='RNN')
plt.plot(lstm_history.history['loss'], label='LSTM')
plt.plot(gru_history.history['loss'], label='GRU')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Comparison")
plt.legend()
plt.show()

# %% [markdown]
# # ✍️ Text Generation Function
# This function predicts the next word repeatedly to generate a sentence.

# %%
def generate_text(model, seed_text, next_words=5):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)[0]

        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# %% [markdown]
# ## 🧪 Generate Text Samples

# %% [markdown]
# Shakespear

# %%
print("RNN :", generate_text(rnn_model, "to be", 10))
print("LSTM:", generate_text(lstm_model, "to be", 10))
print("GRU :", generate_text(gru_model, "to be", 10))
# Out:
# RNN : to be or not to be that is the question of true
# LSTM: to be or not to be that is the question question question
# GRU : to be or not to be that is the question question question

# %% [markdown]
# Song Lyrics

# %%
# print("RNN :", generate_text(rnn_model, "the morning", 10))
# print("LSTM:", generate_text(lstm_model, "the morning", 10))
# print("GRU :", generate_text(gru_model, "the morning", 10))

# %% [markdown]
# Chatbot

# %%
# print("RNN :", generate_text(rnn_model, "user hello", 10))
# print("LSTM:", generate_text(lstm_model, "user hello", 10))
# print("GRU :", generate_text(gru_model, "user hello", 10))

# %% [markdown]
# Story

# %%
# print("RNN :", generate_text(rnn_model, "a young", 10))
# print("LSTM:", generate_text(lstm_model, "a young", 10))
# print("GRU :", generate_text(gru_model, "a young", 10))

# %% [markdown]
# PDF

# %%
# print("RNN :", generate_text(rnn_model, "MAHARISHI MARKANDESHWAR", 10))
# print("LSTM:", generate_text(lstm_model, "MAHARISHI MARKANDESHWAR", 10))
# print("GRU :", generate_text(gru_model, "MAHARISHI MARKANDESHWAR", 10))

# %% [markdown]
# # Comparison Table

# %%
print("Comparison of Models")
print("------------------------------")
print("Vanilla RNN : Fast but struggles with long-term dependencies.")
print("LSTM        : Best memory handling and generates more coherent text.")
print("GRU         : Faster than LSTM with similar performance and fewer parameters.")
# Out:
# Comparison of Models
# ------------------------------
# Vanilla RNN : Fast but struggles with long-term dependencies.
# LSTM        : Best memory handling and generates more coherent text.
# GRU         : Faster than LSTM with similar performance and fewer parameters.

# %% [markdown]
# # 📚 Student Learning Tasks
# ### ✅ Beginner Tasks
# 1. Replace corpus with your own paragraph
# 2. Increase embedding dimension
# 3. Increase epochs to 200
# 4. Change hidden units 64 → 128
# 5. Generate 10 words instead of 5

# %% [markdown]
# # ✅ Conclusion
# - **Vanilla RNN** learns short patterns but struggles with memory
# - **LSTM** captures long-range grammar dependencies better
# - **GRU** gives similar performance with fewer gates and faster training
# - This notebook helps students understand **sequence modeling mathematically and practically**
